# %% [markdown]
# **Theory Questions**

# %% [markdown]
# 1). NumPy (Numerical Python) is a library for numerical computations in Python. It provides support for arrays, matrices, and many mathematical functions. It is fast, efficient, and ideal for handling large datasets and performing vectorized operations.

# %% [markdown]
# 2). Broadcasting allows NumPy to perform arithmetic operations on arrays of different shapes. It automatically expands smaller arrays to match the shape of larger ones without copying data.

# %% [markdown]
# 3). A DataFrame is a 2D labeled data structure in Pandas, similar to a spreadsheet or SQL table, with rows and columns. It can store different types of data.

# %% [markdown]
# 4). groupby() splits data into groups based on some criteria, applies a function to each group independently, and combines the results. It’s commonly used for aggregation.

# %% [markdown]
# 5). Seaborn simplifies the creation of complex visualizations like heatmaps, violin plots, and pair plots. It integrates well with Pandas and adds aesthetic improvements to Matplotlib.

# %% [markdown]
# 6). NumPy arrays are more compact, faster, and support vectorized operations. Lists are more flexible but slower and use more memory.

# %% [markdown]
# 7). A heatmap is a graphical representation of data using colors to represent values. It is used to show the magnitude of a phenomenon as color in two dimensions.

# %% [markdown]
# 8). It refers to applying operations on entire arrays without explicit loops, leading to faster and more concise code.

# %% [markdown]
# 9). Matplotlib is static and simple, best for basic plotting. Plotly provides interactive, web-ready visualizations.

# %% [markdown]
# 10). It allows multiple index levels on an axis. It’s useful for working with higher-dimensional data in a 2D DataFrame.

# %% [markdown]
# 11). pairplot() creates pairwise scatter plots for all numerical features, making it easy to visualize relationships and distributions.

# %% [markdown]
# 12). describe() generates descriptive statistics (mean, std, min, max, etc.) for numeric columns.

# %% [markdown]
# 13). Missing data can distort analysis and models. Pandas offers tools to fill, drop, or interpolate missing values effectively.

# %% [markdown]
# 14). Plotly enables interactive charts with zoom, hover, and click features. It is useful for dashboards and web applications.

# %% [markdown]
# 15).NumPy uses ndarray objects that can have any number of dimensions, enabling efficient mathematical operations and reshaping.

# %% [markdown]
# 16). Bokeh is used for creating interactive and real-time web-ready visualizations with high performance for large datasets.

# %% [markdown]
# 17). map() is used for element-wise transformations on Series.
#
# apply() is more versatile, used on both Series and DataFrames for row/column-wise operations.

# %% [markdown]
# 18). Broadcasting, advanced indexing, masked arrays, FFT, linear algebra operations, and random number generation.

# %% [markdown]
# 19). Pandas provides built-in support for datetime indexing, resampling, frequency conversion, rolling windows, and time zone handling.

# %% [markdown]
# 20). A pivot table summarizes data (e.g., average, sum) based on one or more keys. It reshapes DataFrames in a meaningful way.

# %% [markdown]
# 21). NumPy arrays are stored in contiguous memory and support slicing as a view (no data copying), while list slicing involves copying elements.

# %% [markdown]
# 22). Visualizing distributions, comparing categories, plotting relationships, heatmaps, pairwise plots, and regression lines.

# %% [markdown]
# **PRACTICAL QUESTIONS**

# %%
#1
import numpy as np
arr = np.array([[1, 2, 3], [4, 5, 6]])
row_sum = arr.sum(axis=1)

# %%
#2
import pandas as pd
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
mean_b = df['B'].mean()

# %%
#3
import matplotlib.pyplot as plt
x = [1, 2, 3]
y = [4, 5, 6]
plt.scatter(x, y)
plt.show()

# %%
#4
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({'A': [1,2,3], 'B':[4,5,6], 'C':[7,8,9]})
corr = df.corr()
sns.heatmap(corr, annot=True)
plt.show()

# %%
#5
import plotly.express as px
df = pd.DataFrame({'Name': ['A', 'B'], 'Value': [10, 20]})
fig = px.bar(df, x='Name', y='Value')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#7
import numpy as np
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])
result = a * b

# %%
#8
plt.plot([1, 2, 3], [4, 5, 6], label='Line 1')
plt.plot([1, 2, 3], [6, 5, 4], label='Line 2')
plt.legend()
plt.show()

# %%
#9
df = pd.DataFrame({'A': [10, 20, 5]})
filtered_df = df[df['A'] > 10]

# %%
#10
sns.histplot(df['A'])
plt.show()

# %%
#11
a = np.array([[1, 2], [3, 4]])
b = np.array([[5, 6], [7, 8]])
result = np.dot(a, b)

# %%
#13
import plotly.express as px
df = pd.DataFrame({
    'x': [1, 2, 3],
    'y': [4, 5, 6],
    'z': [7, 8, 9]
})
fig = px.scatter_3d(df, x='x', y='y', z='z')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
